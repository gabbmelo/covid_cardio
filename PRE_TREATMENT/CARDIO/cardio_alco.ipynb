# %%
# %pip install pandas

# %%
# %pip install sklearn
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post10-py3-none-any.whl size=2981 sha256=61ae3c20c0d064f6e2f29c866c7ef6308db0c4d64453a0588bcb9a72fa1febeb
#   Stored in directory: c:\users\gabriel\appdata\local\pip\cache\wheels\e8\33\44\f35b7e846629ac67489632a758c99e5cb17e800d21dcf4c568
# Successfully built sklearn
# ...

# %%
# %pip install numpy

# %%
# %pip install dtreeviz
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/47.0 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/47.0 kB ? eta -:--:--
#      --------------------------------- ---- 41.0/47.0 kB 495.5 kB/s eta 0:00:01
#      -------------------------------------- 47.0/47.0 kB 471.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 3.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/91.8 kB ? eta -:--:--
#    ---------------------------------------- 91.8/91.8 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.1 MB 20.0 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/9.1 MB 16.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/9.1 MB 16.4 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from IPython.display import Image, display_svg, SVG
import warnings
import dtreeviz as dtree
import seaborn as sns

# %%
df = pd.read_csv('cardio_alco.csv', sep=';')
df
# Out:
#           id  alco
# 0         44     0
# 1         45     0
# 2         46     0
# 3         47     0
# 4         49     0
# ...      ...   ...
# 56898  99949     0
# 56899  99950     0
# 56900  99951     0
# 56901  99952     0
# 56902  99954     0
#
# [56903 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56903 entries, 0 to 56902
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      56903 non-null  int64
#  1   alco    56903 non-null  int64
# dtypes: int64(2)
# memory usage: 889.2 KB

# %%
df.isna()
# Out:
#           id   alco
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 56898  False  False
# 56899  False  False
# 56900  False  False
# 56901  False  False
# 56902  False  False
#
# [56903 rows x 2 columns]

# %%
df.describe()
# Out:
#                  id          alco
# count  56903.000000  56903.000000
# mean   48472.162065      0.053442
# std    30994.121701      0.224915
# min       44.000000      0.000000
# 25%    20401.000000      0.000000
# 50%    40763.000000      0.000000
# 75%    77109.500000      0.000000
# max    99954.000000      1.000000

# %%
#quem consome álcool e quem não consome álcool. ID está ligeiramente diferente do arquivo cardio_base
